# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\yasmi\\Downloads\\laptop_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.drop(columns=["Unnamed: 0"],inplace = True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
#Removing GB Word from RAM column
#Removing kg Word from Weight column
df["Ram"] = df["Ram"].str.replace("GB"," ")
df["Weight"] = df["Weight"].str.replace("kg"," ")

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8             128GB SSD
# 1        Intel Core i5 1.8GHz   8   128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8             256GB SSD
# 3        Intel Core i7 2.7GHz  16             512GB SSD
# 4        Intel Core i5 3.1GHz   8             256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37    71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34    47895.5232
# 2         Intel HD Graphics 620  No OS  1.86    30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83   135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37    96095.8080

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   object
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price             1303 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 112.1+ KB

# %%
#Still the RAM and Weight are in object type. We need to convert RAM into integer and Weight into float.

df['Ram'] = df['Ram'].astype('int32')
df['Weight'] = df['Weight'].astype('float32')

# %%
df.info() #Now, RAM is in integer and Weight is in float
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %%
#Performing EDA on our data
import seaborn as sns

# %%
#Checking the Price ranges and its density
sns.distplot(df['Price'])
# Out:
# C:\Users\yasmi\AppData\Local\Temp\ipykernel_15632\1025580001.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
#Checking the count of Laptops for each Company
df['Company'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#Checking the average Price of the laptops with respect to the company.
import matplotlib.pyplot as plt
sns.barplot(x=df["Company"],y=df["Price"])
plt.xticks(rotation='vertical')
plt.show()

# %%
#Checking for the count of Laptops with respect to its type
df["TypeName"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
#Checking the Price of the laptops with respect to the Type.
sns.barplot(x=df["TypeName"],y=df["Price"])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df["Inches"])
# Out:
# C:\Users\yasmi\AppData\Local\Temp\ipykernel_15632\2945259378.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Inches"])
# <AxesSubplot:xlabel='Inches', ylabel='Density'>

# %%
sns.scatterplot(x=df["Inches"],y=df["Price"])
# Out:
# <AxesSubplot:xlabel='Inches', ylabel='Price'>

# %%
df["ScreenResolution"].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Retina Display 2880x1800                 4
# IPS Panel Touchscreen 1920x1200                    4
# 1440x900                                           4
# IPS Panel 2560x1440                                4
# IPS Panel Quad HD+ 2560x1440                       3
# Quad HD+ 3200x1800                                 3
# 1920x1080                                          3
# Touchscreen 2400x1600                              3
# 2560x1440                                          3
# IPS Panel Touchscreen 1366x768                     3
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# IPS Panel Full HD 2160x1440                        2
# IPS Panel Quad HD+ 3200x1800                       2
# IPS Panel Retina Display 2736x1824                 1
# IPS Panel Full HD 1920x1200                        1
# IPS Panel Full HD 2560x1440                        1
# IPS Panel Full HD 1366x768                         1
# Touchscreen / Full HD 1920x1080                    1
# Touchscreen / Quad HD+ 3200x1800                   1
# Touchscreen / 4K Ultra HD 3840x2160                1
# IPS Panel Touchscreen 2400x1600                    1
# Name: ScreenResolution, dtype: int64

# %%
df["Touchscreen"] = df["ScreenResolution"].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df.sample(10)
# Out:
#       Company            TypeName  Inches  \
# 264      Dell            Notebook    15.6
# 693    Lenovo  2 in 1 Convertible    14.0
# 350      Dell            Notebook    15.6
# 183   Toshiba            Notebook    15.6
# 142    Lenovo              Gaming    15.6
# 188      Acer           Ultrabook    13.3
# 1218   Lenovo              Gaming    15.6
# 821   Toshiba           Ultrabook    14.0
# 863    Lenovo              Gaming    15.6
# 913        HP            Notebook    15.6
#
#                          ScreenResolution                          Cpu  Ram  \
# 264                     Full HD 1920x1080   Intel Core i5 7200U 2.5GHz    8
# 693                 Touchscreen 2560x1440   Intel Core i7 7500U 2.7GHz    8
# 350   4K Ultra HD / Touchscreen 3840x2160  Intel Core i7 7700HQ 2.8GHz   16
# 183                              1366x768   Intel Core i5 7200U 2.5GHz    8
# 142           IPS Panel Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz    8
# 188           IPS Panel Full HD 1920x1080    Intel Core i5 7Y54 1.2GHz    8
# 1218          IPS Panel Full HD 1920x1080  Intel Core i7 6700HQ 2.6GHz    8
# 821                              1366x768   Intel Core i5 7200U 2.5GHz    4
# 863           IPS Panel Full HD 1920x1080  Intel Core i5 7300HQ 2.5GHz    8
# 913                     Full HD 1920x1080   Intel Core i7 7500U 2.7GHz    8
#
#                     Memory                             Gpu       OpSys  \
# 264                1TB HDD              AMD Radeon R5 M430  Windows 10
# 693              256GB SSD           Intel HD Graphics 620  Windows 10
# 350              512GB SSD         Nvidia GeForce GTX 1050  Windows 10
# 183              128GB SSD           Intel HD Graphics 620  Windows 10
# 142              256GB SSD        Nvidia GeForce GTX 1050M       No OS
# 188              256GB SSD           Intel HD Graphics 615  Windows 10
# 1218  128GB SSD +  1TB HDD  Nvidia GeForce GTX 960<U+039C>  Windows 10
# 821              128GB SSD           Intel HD Graphics 620  Windows 10
# 863                1TB HDD         Nvidia GeForce GTX 1050       No OS
# 913              256GB SSD            Nvidia GeForce 930MX  Windows 10
#
#       Weight        Price  Touchscreen
# 264     2.24   30103.2000            0
# 693     1.42  137995.2000            1
# 350     2.06  108020.9376            1
# 183     2.00   42251.0400            0
# 142     2.40   46300.3200            0
# 188     1.12   52693.9200            0
# 1218    2.60   67772.1600            0
# 821     1.25   58075.2000            0
# 863     2.50   54185.7600            0
# 913     2.04   54291.7872            0

# %%
df["Touchscreen"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df["Touchscreen"],y=df["Price"])
# Out:
# <AxesSubplot:xlabel='Touchscreen', ylabel='Price'>

# %%
df["IPS"] = df["ScreenResolution"].apply(lambda x:1 if 'IPS' in x else 0)
df.sample(10)
# Out:
#      Company            TypeName  Inches                 ScreenResolution  \
# 1224    Dell  2 in 1 Convertible    15.0  Full HD / Touchscreen 1920x1080
# 405     Asus           Ultrabook    14.0                Full HD 1920x1080
# 902     Dell  2 in 1 Convertible    13.3  Full HD / Touchscreen 1920x1080
# 73       MSI              Gaming    17.3                Full HD 1920x1080
# 664      MSI              Gaming    17.3                Full HD 1920x1080
# 897       HP            Notebook    15.6                Full HD 1920x1080
# 1073      HP            Notebook    13.3                Full HD 1920x1080
# 967       HP            Notebook    15.6                Full HD 1920x1080
# 673   Lenovo            Notebook    15.6                         1366x768
# 1216    Acer            Notebook    17.3                         1600x900
#
#                               Cpu  Ram                Memory  \
# 1224   Intel Core i3 7100U 2.4GHz    4             500GB HDD
# 405    Intel Core i7 7500U 2.7GHz    8             512GB SSD
# 902     Intel Core i7 7Y75 1.3GHz   16             256GB SSD
# 73    Intel Core i5 7300HQ 2.5GHz    8  128GB SSD +  1TB HDD
# 664   Intel Core i7 7700HQ 2.8GHz    8  128GB SSD +  1TB HDD
# 897    Intel Core i7 7500U 2.7GHz    8               1TB HDD
# 1073   Intel Core i7 7500U 2.7GHz    8             256GB SSD
# 967    Intel Core i3 7100U 2.4GHz    4             500GB HDD
# 673   AMD E-Series E2-9000 2.2GHz    4             128GB SSD
# 1216     Intel Core i3 6006U 2GHz    4               1TB HDD
#
#                           Gpu       OpSys  Weight       Price  Touchscreen  \
# 1224    Intel HD Graphics 620  Windows 10    2.08  27119.5200            1
# 405     Intel HD Graphics 620  Windows 10    1.10  99793.4400            0
# 902     Intel HD Graphics 615  Windows 10    1.22  87858.7200            1
# 73    Nvidia GeForce GTX 1050  Windows 10    2.70  58341.6000            0
# 664   Nvidia GeForce GTX 1060  Windows 10    2.70  79215.1056            0
# 897      Nvidia GeForce 930MX  Windows 10    2.04  47952.0000            0
# 1073    Intel HD Graphics 620  Windows 10    1.49  58075.2000            0
# 967     Intel HD Graphics 620  Windows 10    2.04  36496.8000            0
# 673    AMD Radeon R2 Graphics  Windows 10    2.20  18594.7200            0
# 1216     Nvidia GeForce 940MX  Windows 10    3.30  31861.4400            0
#
#       IPS
# 1224    0
# 405     0
# 902     0
# 73      0
# 664     0
# 897     0
# 1073    0
# 967     0
# 673     0
# 1216    0

# %%
df["IPS"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df["IPS"],y=df["Price"])
# Out:
# <AxesSubplot:xlabel='IPS', ylabel='Price'>

# %%
new = df["ScreenResolution"].str.split("x",n=1,expand=True)

# %%
df["X_resolution"] = new[0]
df["Y_resolution"] = new[1]

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#                     X_resolution Y_resolution
# 0  IPS Panel Retina Display 2560         1600
# 1                           1440          900
# 2                   Full HD 1920         1080
# 3  IPS Panel Retina Display 2880         1800
# 4  IPS Panel Retina Display 2560         1600

# %%
df["X_resolution"] = df["X_resolution"].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#   X_resolution Y_resolution
# 0         2560         1600
# 1         1440          900
# 2         1920         1080
# 3         2880         1800
# 4         2560         1600

# %%
df["X_resolution"]=df["X_resolution"].astype('int64')
df["Y_resolution"]=df["Y_resolution"].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  X_resolution      1303 non-null   int64
#  14  Y_resolution      1303 non-null   int64
# dtypes: float32(1), float64(2), int32(1), int64(4), object(7)
# memory usage: 142.6+ KB

# %%
df.corr()["Price"]
# Out:
# Inches          0.068197
# Ram             0.743007
# Weight          0.210370
# Price           1.000000
# Touchscreen     0.191226
# IPS             0.252208
# X_resolution    0.556529
# Y_resolution    0.552809
# Name: Price, dtype: float64

# %%
df["PPI"]=(((df["X_resolution"]**2)+(df["Y_resolution"]**2))**0.5/df["Inches"]).astype("float")

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#    X_resolution  Y_resolution         PPI
# 0          2560          1600  226.983005
# 1          1440           900  127.677940
# 2          1920          1080  141.211998
# 3          2880          1800  220.534624
# 4          2560          1600  226.983005

# %%
df.corr()["Price"]
# Out:
# Inches          0.068197
# Ram             0.743007
# Weight          0.210370
# Price           1.000000
# Touchscreen     0.191226
# IPS             0.252208
# X_resolution    0.556529
# Y_resolution    0.552809
# PPI             0.473487
# Name: Price, dtype: float64

# %%
df.drop(columns=["ScreenResolution"],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS  X_resolution  Y_resolution         PPI
# 0   71378.6832            0    1          2560          1600  226.983005
# 1   47895.5232            0    0          1440           900  127.677940
# 2   30636.0000            0    0          1920          1080  141.211998
# 3  135195.3360            0    1          2880          1800  220.534624
# 4   96095.8080            0    1          2560          1600  226.983005

# %%
df.drop(columns=["Inches","X_resolution","Y_resolution"],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           PPI
# 0  226.983005
# 1  127.677940
# 2  141.211998
# 3  220.534624
# 4  226.983005

# %%
df["Cpu"].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
df['CPU Name'] = df["Cpu"].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           PPI       CPU Name
# 0  226.983005  Intel Core i5
# 1  127.677940  Intel Core i5
# 2  141.211998  Intel Core i5
# 3  220.534624  Intel Core i7
# 4  226.983005  Intel Core i5

# %%
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df["CPU Brand"] = df["CPU Name"].apply(fetch_processor)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           PPI       CPU Name      CPU Brand
# 0  226.983005  Intel Core i5  Intel Core i5
# 1  127.677940  Intel Core i5  Intel Core i5
# 2  141.211998  Intel Core i5  Intel Core i5
# 3  220.534624  Intel Core i7  Intel Core i7
# 4  226.983005  Intel Core i5  Intel Core i5

# %%
df["CPU Brand"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df["CPU Brand"],y=df["Price"])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=["Cpu","CPU Name"],inplace=True)

# %%
df.sample(10)
# Out:
#       Company     TypeName  Ram                Memory  \
# 870    Lenovo     Notebook    4             500GB HDD
# 140      Acer     Notebook    4               1TB HDD
# 1008       HP     Notebook    8             256GB SSD
# 722    Lenovo    Ultrabook    8             256GB SSD
# 839      Asus     Notebook    8             128GB HDD
# 630      Asus    Ultrabook   16             512GB SSD
# 705      Dell     Notebook    8             256GB SSD
# 593   Samsung     Notebook   16  128GB SSD +  1TB HDD
# 424      Dell       Gaming   16  256GB SSD +  1TB HDD
# 486      Dell  Workstation   16             512GB SSD
#
#                           Gpu       OpSys  Weight        Price  Touchscreen  \
# 870     Intel HD Graphics 620  Windows 10    2.38   56210.4000            0
# 140      Nvidia GeForce MX130  Windows 10    3.00   34898.4000            0
# 1008     Nvidia GeForce 930MX  Windows 10    1.64   55904.5728            0
# 722     Intel HD Graphics 620  Windows 10    1.32   79866.7200            0
# 839     Intel HD Graphics 620  Windows 10    2.30   31435.2000            0
# 630     Intel HD Graphics 620  Windows 10    1.10  101232.0000            0
# 705     Intel HD Graphics 620  Windows 10    2.18   42357.6000            0
# 593   Nvidia GeForce GTX 1050  Windows 10    2.50   90522.7200            0
# 424   Nvidia GeForce GTX 1070  Windows 10    4.42  149130.7200            0
# 486        Nvidia Quadro M620  Windows 10    2.17  124568.6400            0
#
#       IPS         PPI      CPU Brand
# 870     0  100.454670  Intel Core i5
# 140     1  127.335675  Intel Core i3
# 1008    0  157.350512  Intel Core i5
# 722     1  157.350512  Intel Core i5
# 839     0  141.211998  Intel Core i5
# 630     0  157.350512  Intel Core i7
# 705     0  141.211998  Intel Core i5
# 593     0  141.211998  Intel Core i7
# 424     1  169.780899  Intel Core i7
# 486     1  141.211998  Intel Core i7

# %%
df["Ram"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df["Ram"],y=df["Price"])
plt.xticks(rotation='vertical')
plt.show()

# %%
df["Memory"].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB SSD +  256GB SSD             1
# 512GB SSD +  512GB SSD             1
# 64GB Flash Storage +  1TB HDD      1
# 1TB HDD +  1TB HDD                 1
# 32GB HDD                           1
# 64GB SSD                           1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 1.0TB HDD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 256GB SSD +  1.0TB Hybrid          1
# Name: Memory, dtype: int64

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')
new = df["Memory"].str.split("+", n = 1, expand = True)

df["first"]= new[0]
df["first"]=df["first"].str.strip()

df["second"]= new[1]

df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['first'] = df['first'].str.replace(r'\D', '')

df["second"].fillna("0", inplace = True)

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['second'] = df['second'].str.replace(r'\D', '')

df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)

df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)
# Out:
# C:\Users\yasmi\AppData\Local\Temp\ipykernel_15632\4023190604.py:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['first'] = df['first'].str.replace(r'\D', '')
# C:\Users\yasmi\AppData\Local\Temp\ipykernel_15632\4023190604.py:25: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['second'] = df['second'].str.replace(r'\D', '')

# %%
df.sample(10)
# Out:
#       Company            TypeName  Ram       Memory                      Gpu  \
# 886      Dell            Notebook    4     1000 HDD      AMD Radeon R5 M420X
# 490    Lenovo            Notebook    8      256 SSD     Nvidia GeForce 940MX
# 1260   Lenovo  2 in 1 Convertible    4      128 SSD    Intel HD Graphics 520
# 561    Lenovo            Notebook    4      128 SSD    Intel HD Graphics 620
# 1174   Lenovo            Notebook    8     1000 HDD     Nvidia GeForce 940MX
# 782   Toshiba           Ultrabook   16      512 SSD      Nvidia GeForce 930M
# 1176   Lenovo            Notebook    4  1000 Hybrid    Intel HD Graphics 520
# 1298   Lenovo  2 in 1 Convertible    4      128 SSD    Intel HD Graphics 520
# 680       MSI              Gaming    8      256 SSD  Nvidia GeForce GTX 1050
# 752      Asus            Notebook    4     1000 HDD  Nvidia GeForce GTX 950M
#
#            OpSys  Weight       Price  Touchscreen  IPS         PPI  \
# 886        Linux    2.18  24279.6960            0    0  100.454670
# 490   Windows 10    2.30  53918.8272            0    1  141.211998
# 1260  Windows 10    1.80  44382.7728            1    0  157.350512
# 561   Windows 10    2.05  33566.4000            0    0  141.211998
# 1174       No OS    2.20  37775.5200            0    0  141.211998
# 782   Windows 10    1.47  93985.9200            0    1  157.350512
# 1176   Windows 7    2.32  43956.0000            0    0  141.211998
# 1298  Windows 10    1.80  33992.6400            1    1  157.350512
# 680   Windows 10    2.20  53168.1120            0    0  141.211998
# 752        No OS    2.45  30849.1200            0    0  100.454670
#
#           CPU Brand   HDD  SSD  Hybrid  Flash_Storage
# 886   Intel Core i3  1000    0       0              0
# 490   Intel Core i5     0  256       0              0
# 1260  Intel Core i5     0  128       0              0
# 561   Intel Core i3     0  128       0              0
# 1174  Intel Core i7  1000    0       0              0
# 782   Intel Core i7     0  512       0              0
# 1176  Intel Core i7     0    0    1000              0
# 1298  Intel Core i7     0  128       0              0
# 680   Intel Core i5     0  256       0              0
# 752   Intel Core i5  1000    0       0              0

# %%
df.drop(columns=["Memory"],inplace=True)

# %%
df.corr()["Price"]
# Out:
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# Touchscreen      0.191226
# IPS              0.252208
# PPI              0.473487
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
df.drop(columns=["Hybrid","Flash_Storage"],inplace = True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS         PPI      CPU Brand  HDD  SSD
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256

# %%
df["Gpu"].value_counts()
# Out:
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: Gpu, Length: 110, dtype: int64

# %%
df["Gpu"] = df["Gpu"].apply(lambda x:x.split()[0])

# %%
df.sample(10)
# Out:
#      Company            TypeName  Ram     Gpu       OpSys  Weight       Price  \
# 269   Lenovo            Notebook    8   Intel  Windows 10    2.05   46886.400
# 1107  Lenovo  2 in 1 Convertible    4   Intel  Windows 10    2.10   46193.760
# 1299  Lenovo  2 in 1 Convertible   16   Intel  Windows 10    1.30   79866.720
# 1265  Lenovo            Notebook    8  Nvidia  Windows 10    2.60   47898.720
# 1096    Dell            Notebook    8     AMD  Windows 10    2.36   34035.264
# 1098      HP            Notebook    4   Intel  Windows 10    1.96   26640.000
# 256       HP            Notebook    8     AMD  Windows 10    1.91   23757.552
# 207     Dell           Ultrabook    8   Intel  Windows 10    1.21  103842.720
# 684   Lenovo  2 in 1 Convertible    8   Intel  Windows 10    1.19   79866.720
# 1233     MSI              Gaming   16  Nvidia  Windows 10    2.70   85141.440
#
#       Touchscreen  IPS         PPI              CPU Brand   HDD  SSD
# 269             0    0  141.211998          Intel Core i7     0  256
# 1107            1    1  141.211998          Intel Core i5     0  256
# 1299            1    1  276.053530          Intel Core i7     0  512
# 1265            0    1  141.211998          Intel Core i7  1000    0
# 1096            0    0  141.211998          Intel Core i5  1000    0
# 1098            0    0  100.454670  Other Intel Processor  1000    0
# 256             0    0  100.454670          AMD Processor     0  128
# 207             1    1  331.264236          Intel Core i7     0  256
# 684             1    1  165.632118          Intel Core i7     0  512
# 1233            0    0  127.335675          Intel Core i7  1000  256

# %%
df["Gpu"].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: Gpu, dtype: int64

# %%
df = df[df["Gpu"] != "ARM"]

# %%
df["Gpu"].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# Name: Gpu, dtype: int64

# %%
sns.barplot(x=df["Gpu"],y=df["Price"])
plt.xticks(rotation='vertical')
plt.show()

# %%
df["OpSys"].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
sns.barplot(x=df["OpSys"],y=df["Price"])
plt.xticks(rotation='vertical')
plt.show()

# %%
def cat_OS(inp):
    if inp=="Windows 10" or inp=="Windows 7" or inp == "Windows 10 S":
        return "Windows"
    elif inp=="macOS" or inp == "Mac OS X":
        return "Mac"
    else:
        return "Others/No OS/Linux"

# %%
df["OS"] = df["OpSys"].apply(cat_OS)

# %%
df.head()
# Out:
#   Company   TypeName  Ram    Gpu  OpSys  Weight        Price  Touchscreen  \
# 0   Apple  Ultrabook    8  Intel  macOS    1.37   71378.6832            0
# 1   Apple  Ultrabook    8  Intel  macOS    1.34   47895.5232            0
# 2      HP   Notebook    8  Intel  No OS    1.86   30636.0000            0
# 3   Apple  Ultrabook   16    AMD  macOS    1.83  135195.3360            0
# 4   Apple  Ultrabook    8  Intel  macOS    1.37   96095.8080            0
#
#    IPS         PPI      CPU Brand  HDD  SSD                  OS
# 0    1  226.983005  Intel Core i5    0  128                 Mac
# 1    0  127.677940  Intel Core i5    0    0                 Mac
# 2    0  141.211998  Intel Core i5    0  256  Others/No OS/Linux
# 3    1  220.534624  Intel Core i7    0  512                 Mac
# 4    1  226.983005  Intel Core i5    0  256                 Mac

# %%
df.drop(columns=["OpSys"],inplace = True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram    Gpu  Weight        Price  Touchscreen  IPS  \
# 0   Apple  Ultrabook    8  Intel    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  Intel    1.34   47895.5232            0    0
# 2      HP   Notebook    8  Intel    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16    AMD    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  Intel    1.37   96095.8080            0    1
#
#           PPI      CPU Brand  HDD  SSD                  OS
# 0  226.983005  Intel Core i5    0  128                 Mac
# 1  127.677940  Intel Core i5    0    0                 Mac
# 2  141.211998  Intel Core i5    0  256  Others/No OS/Linux
# 3  220.534624  Intel Core i7    0  512                 Mac
# 4  226.983005  Intel Core i5    0  256                 Mac

# %%
sns.barplot(x=df["OS"],y=df["Price"])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df["Weight"])
# Out:
# C:\Users\yasmi\AppData\Local\Temp\ipykernel_15632\196129849.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Weight"])
# <AxesSubplot:xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x=df["Weight"],y=df["Price"])
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Price'>

# %%
df.corr()["Price"]
# Out:
# Ram            0.742905
# Weight         0.209867
# Price          1.000000
# Touchscreen    0.192917
# IPS            0.253320
# PPI            0.475368
# HDD           -0.096891
# SSD            0.670660
# Name: Price, dtype: float64

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.distplot(np.log(df["Price"]))#Since our target Variable is skewed, it can cause problems to our model.Hence applying log transformations.
# Out:
# C:\Users\yasmi\AppData\Local\Temp\ipykernel_15632\3588644405.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df["Price"]))#Since our target Variable is skewed, it can cause problems to our model.Hence applying log transformations.
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
X = df.drop(columns=["Price"])
Y = np.log(df["Price"])

# %%
X
# Out:
#      Company            TypeName  Ram    Gpu  Weight  Touchscreen  IPS  \
# 0      Apple           Ultrabook    8  Intel    1.37            0    1
# 1      Apple           Ultrabook    8  Intel    1.34            0    0
# 2         HP            Notebook    8  Intel    1.86            0    0
# 3      Apple           Ultrabook   16    AMD    1.83            0    1
# 4      Apple           Ultrabook    8  Intel    1.37            0    1
# ...      ...                 ...  ...    ...     ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible    4  Intel    1.80            1    1
# 1299  Lenovo  2 in 1 Convertible   16  Intel    1.30            1    1
# 1300  Lenovo            Notebook    2  Intel    1.50            0    0
# 1301      HP            Notebook    6    AMD    2.19            0    0
# 1302    Asus            Notebook    4  Intel    2.20            0    0
#
#              PPI              CPU Brand   HDD  SSD                  OS
# 0     226.983005          Intel Core i5     0  128                 Mac
# 1     127.677940          Intel Core i5     0    0                 Mac
# 2     141.211998          Intel Core i5     0  256  Others/No OS/Linux
# 3     220.534624          Intel Core i7     0  512                 Mac
# 4     226.983005          Intel Core i5     0  256                 Mac
# ...          ...                    ...   ...  ...                 ...
# 1298  157.350512          Intel Core i7     0  128             Windows
# 1299  276.053530          Intel Core i7     0  512             Windows
# 1300  111.935204  Other Intel Processor     0    0             Windows
# 1301  100.454670          Intel Core i7  1000    0             Windows
# 1302  100.454670  Other Intel Processor   500    0             Windows
#
# [1302 rows x 12 columns]

# %%
Y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size = 0.15,random_state=2)

# %%
X_train
# Out:
#       Company            TypeName  Ram     Gpu  Weight  Touchscreen  IPS  \
# 183   Toshiba            Notebook    8   Intel    2.00            0    0
# 1141      MSI              Gaming    8  Nvidia    2.40            0    0
# 1049     Asus             Netbook    4   Intel    1.20            0    0
# 1020     Dell  2 in 1 Convertible    4   Intel    2.08            1    1
# 878      Dell            Notebook    4  Nvidia    2.18            0    0
# ...       ...                 ...  ...     ...     ...          ...  ...
# 466      Acer            Notebook    4  Nvidia    2.20            0    0
# 299      Asus           Ultrabook   16  Nvidia    1.63            0    0
# 493      Acer            Notebook    8     AMD    2.20            0    0
# 527    Lenovo            Notebook    8  Nvidia    2.20            0    0
# 1193    Apple           Ultrabook    8   Intel    0.92            0    1
#
#              PPI              CPU Brand   HDD  SSD                  OS
# 183   100.454670          Intel Core i5     0  128             Windows
# 1141  141.211998          Intel Core i7  1000  128             Windows
# 1049  135.094211  Other Intel Processor     0    0  Others/No OS/Linux
# 1020  141.211998          Intel Core i3  1000    0             Windows
# 878   141.211998          Intel Core i5  1000  128             Windows
# ...          ...                    ...   ...  ...                 ...
# 466   100.454670          Intel Core i3   500    0             Windows
# 299   141.211998          Intel Core i7     0  512             Windows
# 493   100.454670          AMD Processor  1000    0             Windows
# 527   100.454670          Intel Core i3  2000    0  Others/No OS/Linux
# 1193  226.415547  Other Intel Processor     0    0                 Mac
#
# [1106 rows x 12 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in d:\anaconda3\lib\site-packages (1.7.6)
# Requirement already satisfied: numpy in d:\anaconda3\lib\site-packages (from xgboost) (1.21.5)
# Requirement already satisfied: scipy in d:\anaconda3\lib\site-packages (from xgboost) (1.9.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error
step1 = ColumnTransformer(transformers=[("col_tnf",OneHotEncoder(sparse=False,drop='first'),[0,1,3,8,11])],remainder='passthrough')
step2 = LinearRegression()
pipe = Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)
print("R2 score",r2_score(y_test,y_pred))
print("Mean Absolute Error",mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8073277448418643
# Mean Absolute Error 0.21017827976428846

# %%
df.head(1)
# Out:
#   Company   TypeName  Ram    Gpu  Weight       Price  Touchscreen  IPS  \
# 0   Apple  Ultrabook    8  Intel    1.37  71378.6832            0    1
#
#           PPI      CPU Brand  HDD  SSD   OS
# 0  226.983005  Intel Core i5    0  128  Mac

# %% [markdown]
# # Random Forest

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,3,8,11])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8845990718367212
# MAE 0.1596617556124746

# %% [markdown]
# # Gradient Descent

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,3,8,11])
],remainder='passthrough')

step2 = GradientBoostingRegressor(n_estimators=500)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8827639743971926
# MAE 0.15921150807013223

# %% [markdown]
# # XgBoost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,3,8,11])
],remainder='passthrough')

step2 = XGBRegressor(n_estimators=45,max_depth=5,learning_rate=0.5)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8817952922286948
# MAE 0.16441286858586562

# %% [markdown]
# # AdaBoost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,3,8,11])
],remainder='passthrough')

step2 = AdaBoostRegressor(n_estimators=15,learning_rate=1.0)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7730488843755335
# MAE 0.2386058056125062

# %% [markdown]
# # Voting Regressor

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,3,8,11])
],remainder='passthrough')


rf = RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)
gbdt = GradientBoostingRegressor(n_estimators=100,max_features=0.5)
xgb = XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5)


step2 = VotingRegressor([('rf', rf), ('gbdt', gbdt), ('xgb',xgb)],weights=[5,1,1])

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8872258925981544
# MAE 0.1599015590690235

# %% [markdown]
# # Stacking

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,3,8,11])
],remainder='passthrough')


estimators = [
    ('rf', RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)),
    ('gbdt',GradientBoostingRegressor(n_estimators=100,max_features=0.5)),
    ('xgb', XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5))
]

step2 = StackingRegressor(estimators=estimators, final_estimator=Ridge(alpha=100))

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8795557195879502
# MAE 0.16786515689500722

# %% [markdown]
# # Exporting the Model

# %%
import pickle

pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))
